# %%
import pandas as pd

# %%
df1 = pd.read_csv('webtoon_info.csv', index_col=0)
df2 = pd.read_csv('webtoon_info2.csv', index_col=0)

# %%
df1.head()
# Out:
#          title illustrator writer platform
# 0        바른쀼생활          윤박     윤박   lezhin
# 1        바퀴멘터리         박바퀴    박바퀴   lezhin
# 2     커튼콜 아래그랑        바싹탄숯   바싹탄숯   lezhin
# 3     꼴데툰 2021        샤다라빠   샤다라빠   lezhin
# 4  citrus 시트러스       사부로우타  사부로우타   lezhin

# %%
df2.head()
# Out:
#         title                                         url  \
# 0         천지해  https://www.lezhin.com/ko/comic/cheonjihae
# 1  여우비 내리는 날에     https://www.lezhin.com/ko/comic/foxrain
# 2      정당한 기만       https://www.lezhin.com/ko/comic/giman
# 3        부랄친구         https://www.lezhin.com/ko/comic/bff
# 4    꼴데툰 2021  https://www.lezhin.com/ko/comic/ggtoon2021
#
#                                              img_src    genre
# 0  https://ccdn.lezhin.com/v2/comics/59/images/th...  fantasy
# 1  https://ccdn.lezhin.com/v2/comics/590167373545...   school
# 2  https://ccdn.lezhin.com/v2/comics/567525214158...       bl
# 3  https://ccdn.lezhin.com/v2/comics/547437938343...      gag
# 4  https://ccdn.lezhin.com/v2/comics/669029457598...      gag

# %%
aa = pd.merge(left = df1 , right = df2, how = "inner", on = "title")

# %%
aa.head()
# Out:
#    title illustrator writer platform  \
# 0  바른쀼생활          윤박     윤박   lezhin
# 1  바퀴멘터리         박바퀴    박바퀴   lezhin
# 2  바퀴멘터리         박바퀴    박바퀴   lezhin
# 3  바퀴멘터리         박바퀴    박바퀴   lezhin
# 4  바퀴멘터리         박바퀴    박바퀴   lezhin
#
#                                             url  \
# 0        https://www.lezhin.com/ko/comic/20_nov
# 1  https://www.lezhin.com/ko/comic/baquimentary
# 2  https://www.lezhin.com/ko/comic/baquimentary
# 3  https://www.lezhin.com/ko/comic/baquimentary
# 4  https://www.lezhin.com/ko/comic/baquimentary
#
#                                              img_src genre
# 0  https://ccdn.lezhin.com/v2/comics/456616104152...   day
# 1  https://ccdn.lezhin.com/v2/comics/618583338739...   day
# 2  https://ccdn.lezhin.com/v2/comics/618583338739...   day
# 3  https://ccdn.lezhin.com/v2/comics/618583338739...   day
# 4  https://ccdn.lezhin.com/v2/comics/618583338739...   day

# %%
aa.to_csv('lezhin_webtoon_info.csv', encoding='utf-8-sig')
