# %%
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
import urllib
import urllib.request
from selenium.common.exceptions import NoSuchElementException
import time
import pyautogui


URL = 'https://webtoon.kakao.com/original-webtoon?tab=mon'

driver = webdriver.Chrome(executable_path='C:/chromedriver')
driver.implicitly_wait(time_to_wait=1)
driver.get(URL)

#Vedio 웹툰
for i in range(1,8):
    driver.find_element_by_xpath('//*[@id="root"]/main/div/div[1]/div[1]/div[3]/div[2]/div[2]/ul/li['+str(i+1)+']/p').click()
    time.sleep(1)
    
    first = driver.find_element_by_xpath('//*[@id="root"]/main/div/div[1]/div[2]/div/div[3]/div/div/div/div/div/div['+str(i)+']/div[3]/div[1]/div/div/div/div/div/a/video')
    first.click()
    time.sleep(1)

    pyautogui.mouseDown()
    
    for i in range(1,11):
        pyautogui.scroll(-1000)
        time.sleep(1)
        
    for i in range(1,11):
        pyautogui.scroll(1000)
        time.sleep(1)


    img_url = driver.find_elements_by_xpath('//*[@id="root"]/main/div/div[2]/div/div[1]/div[3]/div/div/div[1]/div/div[2]/div/div[1]/div/div/div/div/ul/li/a/div[1]/div/picture/img')
#     len(img_url)

    img_list = []

    for img in img_url:
        img_list.append(img.get_attribute('src'))

    print(img_list)
    time.sleep(1)
    
    driver.find_element_by_xpath('//*[@id="root"]/main/div/div[2]/div/div[1]/div[1]/div[1]/div[1]/img').click()
    time.sleep(1)
    
driver.close()

# %%
#image 웹툰
URL = 'https://webtoon.kakao.com/original-webtoon?tab=mon'

driver = webdriver.Chrome(executable_path='C:/chromedriver')
driver.implicitly_wait(time_to_wait=1)
driver.get(URL)
# //*[@id="root"]/main/div/div[1]/div[2]/div/div[3]/div/div/div/div/div/div[1]/div[3]/div[2]/div/div/div/div/a/picture/img
j = 2
#Vedio 웹툰
for i in range(1,8):
    driver.find_element_by_xpath('//*[@id="root"]/main/div/div[1]/div[1]/div[3]/div[2]/div[2]/ul/li['+str(i+1)+']/p').click()
    time.sleep(1)
    
    
    first = driver.find_element_by_xpath('//*[@id="root"]/main/div/div[1]/div[2]/div/div[3]/div/div/div/div/div/div['+str(i)+']/div[3]/div['+str(j)+']/div/div/div/div/a')
    first.click()
    time.sleep(1)

    pyautogui.mouseDown()

    for i in range(1,11):
        pyautogui.scroll(-1000)
        time.sleep(1)

    for i in range(1,11):
        pyautogui.scroll(1000)
        time.sleep(1)


    img_url = driver.find_elements_by_xpath('//*[@id="root"]/main/div/div[2]/div/div[1]/div[3]/div/div/div[1]/div/div[2]/div/div[1]/div/div/div/div/ul/li/a/div[1]/div/picture/img')
#     len(img_url)

    img_list = []

    for img in img_url:
        img_list.append(img.get_attribute('src'))

    print(img_list)
    time.sleep(1)

    driver.find_element_by_xpath('//*[@id="root"]/main/div/div[2]/div/div[1]/div[1]/div[1]/div[1]/img').click()
    time.sleep(1)
        

    
driver.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-b21c76cf2542> in <module>
#      21
#      22     for i in range(1,11):
# ---> 23         pyautogui.scroll(-1000)
#      24         time.sleep(1)
#      25
#
# ~\anaconda3\envs\multi\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     597         failSafeCheck()
#     598         returnVal = wrappedFunction(*args, **kwargs)
# --> 599         _handlePause(kwargs.get("_pause", True))
#     600         return returnVal
#     601
#
# ~\anaconda3\envs\multi\lib\site-packages\pyautogui\__init__.py in _handlePause(_pause)
#     641     if _pause:
#     642         assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 643         time.sleep(PAUSE)
#     644
#     645
#
# KeyboardInterrupt:
