# %%
#데이터 불러오기

import json

with open('weekdays.json', 'r', encoding='utf8') as f:
    contents = f.read()
    json_data = json.loads(contents)

# print(json.dumps(json_data, indent="\t", ensure_ascii=False))
# print(json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['title'])

# 구조 정제

title = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['title']
keyword = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['seoKeywords']
synopsis = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['synopsis']
authors = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['authors']
featuredCharacterImageB = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['featuredCharacterImageB']

# print(title)
# print(keyword)
# print(synopsis)
# print(authors)
# print(featuredCharacterImageB+'.png')

x = 0
y = 0
z = 0

days = []
titles = []
keywords = []
synopsises = []
authorsl = []
main_image = []

while True:
  try:
    xs = json_data['data']['sections'][x]
    while True:
      try:
        ys = xs['cardGroups'][y]
        while True:
          try:
            day = xs['title']
            title = ys['cards'][z]['content']['title']
            keyword = ys['cards'][z]['content']['seoKeywords']
            synopsis = ys['cards'][z]['content']['synopsis']
            authors = ys['cards'][z]['content']['authors']
            images = ys['cards'][z]['content']['featuredCharacterImageB']

            days.append(day)
            titles.append(title)
            keywords.append(keyword)
            synopsises.append(synopsis)
            authorsl.append(authors)
            main_image.append(images)

            z += 1
          except:
            z = 0
            y += 1
            break
      except:
        z = 0
        y = 0
        x += 1
        break
  except:
    break
    
#제목 정제
import re

re_titles = []

for i in range(len(titles)):
    re_titles.append(re.sub('[^0-9a-zA-Zㄱ-힗]','',titles[i]))
    
# re_titles

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
import urllib
import urllib.request
from selenium.common.exceptions import NoSuchElementException
import time
import pyautogui


URL = 'https://webtoon.kakao.com/original-webtoon?tab=mon'

driver = webdriver.Chrome(executable_path='C:/chromedriver')
driver.implicitly_wait(time_to_wait=1)
driver.get(URL)

name = 'name'
ep_num = 3

first = driver.find_element_by_xpath('//*[@id="root"]/main/div/div[1]/div[2]/div/div[3]/div/div/div/div/div/div[1]/div[3]/div[1]/div/div/div/div/div/a/video')
first.click()
time.sleep(1)

# %%
img_url = driver.find_elements_by_xpath('//*[@id="root"]/main/div/div[2]/div/div[1]/div[3]/div/div/div[1]/div/div[2]/div/div[1]/div/div/div/div/ul/li/a/div[1]/div/picture/img')

# %%
len(img_url)
# Out:
# 90

# %%
img_list = []

for img in img_url:
    img_list.append(img.get_attribute('src'))

img_list
# Out:
# ['https://kr-a.kakaopagecdn.com/P/EO/1781/138469/tn/2x/0dcb0726-2ade-41a3-b57e-64127b3ec057.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/138078/tn/2x/e5e2e8b6-0149-447b-9038-acc8b482886d.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/137715/tn/2x/9708df04-9fca-4966-919e-85c0bcdbac2b.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/137224/tn/2x/7f1ba000-0a4f-4cec-9570-bda0f6646b1f.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/136853/tn/2x/dbc70648-62ff-4e1b-b681-41d3511f826f.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/136852/tn/2x/b487afff-2759-4b58-9e35-0c8967d96460.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/136851/tn/2x/943207ff-5103-46e0-b864-796aa7bd977a.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/136850/tn/2x/1c6dad38-151c-471c-8e43-5091a7a1f0e9.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/136849/tn/2x/9c193026-96dd-40e7-bc12-00b5e085bbb8.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/136848/tn/2x/75e423cd-c456-4698-80b3-c1192c72ca8f.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/108959/tn/2x/41af80a1-3f60-4ee3-a2fc-12df2c03babf.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781/107783/tn/2x/46d2e571-181a-4f29-8062-a53872991e3e.jpg',
#  'https://kr-a.kakaopagecdn.com/P/EO/1781