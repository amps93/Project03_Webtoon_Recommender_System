# %%
import pandas as pd

# %%
df1 = pd.read_csv('webtoon_info.csv', index_col=0)
df2 = pd.read_csv('webtoon_info_url.csv', index_col=0)

# %%
df1.head()
# Out:
#      title writer illustrator     genre  \
# 0      참교육    채용택         한가람   스토리, 액션
# 1     신의 탑    SIU         SIU  스토리, 판타지
# 2  뷰티풀 군바리     설이         윤성원  스토리, 드라마
# 3   소녀의 세계    모랑지         모랑지  스토리, 드라마
# 4     팔이피플     매미          희세  스토리, 드라마
#
#                                                story      age
# 0  무너진 교권을 지키기 위해 교권보호국 소속 나화진의 참교육이 시작된다!<부활남> 채...  15세 이용가
# 1      자신의 모든 것이었던 소녀를 쫓아 탑에 들어온 소년그리고 그런 소년을 시험하는 탑  12세 이용가
# 2                     '여자도 군대에 간다면?'본격 여자도 군대 가는 만화!  15세 이용가
# 3  완벽해 보이지만 사실 외로웠던 백조들과 맘씨 착한 오리가 만나여러 갈등을 함께 겪으...    전체연령가
# 4  <마스크걸>, <위대한 방옥숙> 매미/희세 작가의 신작!SNS에서 육아용품 파는 평...  15세 이용가

# %%
df2.head()
# Out:
#      title                                            img_src  \
# 0      참교육  https://shared-comic.pstatic.net/thumb/webtoon...
# 1     신의 탑  https://shared-comic.pstatic.net/thumb/webtoon...
# 2  뷰티풀 군바리  https://shared-comic.pstatic.net/thumb/webtoon...
# 3   소녀의 세계  https://shared-comic.pstatic.net/thumb/webtoon...
# 4     팔이피플  https://shared-comic.pstatic.net/thumb/webtoon...
#
#                                                  url platform
# 0  https://comic.naver.com/webtoon/list?titleId=7...    naver
# 1  https://comic.naver.com/webtoon/list?titleId=1...    naver
# 2  https://comic.naver.com/webtoon/list?titleId=6...    naver
# 3  https://comic.naver.com/webtoon/list?titleId=6...    naver
# 4  https://comic.naver.com/webtoon/list?titleId=7...    naver

# %%
aa = pd.merge(left = df1 , right = df2, how = "inner", on = "title")

# %%
aa.head()
# Out:
#      title writer illustrator     genre  \
# 0      참교육    채용택         한가람   스토리, 액션
# 1     신의 탑    SIU         SIU  스토리, 판타지
# 2  뷰티풀 군바리     설이         윤성원  스토리, 드라마
# 3   소녀의 세계    모랑지         모랑지  스토리, 드라마
# 4     팔이피플     매미          희세  스토리, 드라마
#
#                                                story      age  \
# 0  무너진 교권을 지키기 위해 교권보호국 소속 나화진의 참교육이 시작된다!<부활남> 채...  15세 이용가
# 1      자신의 모든 것이었던 소녀를 쫓아 탑에 들어온 소년그리고 그런 소년을 시험하는 탑  12세 이용가
# 2                     '여자도 군대에 간다면?'본격 여자도 군대 가는 만화!  15세 이용가
# 3  완벽해 보이지만 사실 외로웠던 백조들과 맘씨 착한 오리가 만나여러 갈등을 함께 겪으...    전체연령가
# 4  <마스크걸>, <위대한 방옥숙> 매미/희세 작가의 신작!SNS에서 육아용품 파는 평...  15세 이용가
#
#                                              img_src  \
# 0  https://shared-comic.pstatic.net/thumb/webtoon...
# 1  https://shared-comic.pstatic.net/thumb/webtoon...
# 2  https://shared-comic.pstatic.net/thumb/webtoon...
# 3  https://shared-comic.pstatic.net/thumb/webtoon...
# 4  https://shared-comic.pstatic.net/thumb/webtoon...
#
# ...

# %%
aa.to_csv('naver_webtoon_info.csv', encoding='utf-8-sig')
